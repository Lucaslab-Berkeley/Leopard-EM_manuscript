# %% [markdown]
# # Notebook for reconstructing from untreated data
#
# First, we extract the particle and make the star files.

# %%
import pandas as pd
import mrcfile
import numpy as np
import os
from pathlib import Path
import glob
import starfile
import sys
import random

# Set up the command line arguments
sys.argv = [
    'export_relion_constrained.py',
    'xe30kv/results_all_steps_3/final_results/',
    'xe30kv/results_refine_tm_60S_2/',
    'xe30kv/extracted_60S_constrained_2/',
    '--box-size', '512',
    '--csv-suffix-60s', '_refined_results.csv',
    '--csv-suffix-40s', '_constrained_results_above_threshold.csv'
]

def wrap_angle(angle):
    """Wrap angle from 0-360 to -180 to 180 degrees"""
    return (angle + 180) % 360 - 180

def create_star_file(df, output_dir, output_star_path, box_size) -> None:
    """
    Create a particles.star file from the particle data.
    
    Args:
        df (pandas.DataFrame): DataFrame containing particle data
        output_dir (str): Directory containing the particle stacks
        output_star_path (str): Path to save the star file
        box_size (int): Size of the box used for particle extraction
    """
    # Create a new DataFrame for particles
    particle_df = pd.DataFrame()
    
    # Group by micrograph to get particle indices
    for micrograph_path, particles in df.groupby('micrograph_path'):
        mrcs_name = f"{Path(micrograph_path).stem}.mrcs"
        mrcs_rel_path = os.path.join(output_dir, mrcs_name)
        
        # Add each particle to the particle DataFrame
        for _, particle in particles.iterrows():
            particle_data = {
                'rlnCoordinateX': particle['pos_x'],
                'rlnCoordinateY': particle['pos_y'],
                'rlnImageName': f"{particle['stack_order']:06d}@{mrcs_rel_path}",
                'rlnMicrographName': micrograph_path,  # Use full path
                'rlnOpticsGroup': 1,
                'rlnDefocusU': particle['defocus_u'] + particle['refined_relative_defocus'],
                'rlnDefocusV': particle['defocus_v'] + particle['refined_relative_defocus'],
                'rlnDefocusAngle': particle['astigmatism_angle'],
                'rlnAngleRot': wrap_angle(particle['refined_phi']),
                'rlnAngleTilt': particle['refined_theta'],
                'rlnAnglePsi': wrap_angle(particle['refined_psi']),
                'rlnRandomSubset': random.randint(1, 2)
            }
            particle_df = pd.concat([particle_df, pd.DataFrame([particle_data])], ignore_index=True)
    
    # Create optics DataFrame
    optics_data = {
        'rlnOpticsGroup': 1,
        'rlnOpticsGroupName': 'OpticsGroup1',
        'rlnMicrographOriginalPixelSize': df['refined_pixel_size'].iloc[0],
        'rlnSphericalAberration': df['spherical_aberration'].iloc[0],
        'rlnVoltage': df['voltage'].iloc[0],
        'rlnAmplitudeContrast': df['amplitude_contrast_ratio'].iloc[0],
        'rlnImagePixelSize': df['refined_pixel_size'].iloc[0],
        'rlnImageSize': box_size
    }
    optics_df = pd.DataFrame([optics_data])
    
    # Write the star file
    starfile.write(
        {'optics': optics_df, 'particles': particle_df},
        output_star_path
    )
    print(f"Created star file: {output_star_path}")

def create_particle_stacks(input_40s_dir, input_60s_dir, output_dir, box_size, sort_column='original_offset_psi', 
                         csv_suffix_40s='_results.csv', csv_suffix_60s='_results.csv') -> None:
    """
    Create particle stacks from CSV files containing particle positions.
    
    Args:
        input_40s_dir (str): Directory containing 40S input CSV files
        input_60s_dir (str): Directory containing 60S input CSV files
        output_dir (str): Directory to save the output stacks
        box_size (int): Size of the square box to crop around each particle
        sort_column (str): Column name to use for sorting particles (default: 'original_offset_psi')
        csv_suffix_40s (str): Suffix pattern to match 40S CSV files (default: '_results.csv')
        csv_suffix_60s (str): Suffix pattern to match 60S CSV files (default: '_results.csv')
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Find all CSV files in both directories
    csv_pattern_40s = os.path.join(input_40s_dir, f'*{csv_suffix_40s}')
    csv_pattern_60s = os.path.join(input_60s_dir, f'*{csv_suffix_60s}')
    csv_files_40s = glob.glob(csv_pattern_40s)
    csv_files_60s = glob.glob(csv_pattern_60s)
    
    if not csv_files_40s or not csv_files_60s:
        print("No CSV files found in one or both input directories")
        return
    
    print(f"Found {len(csv_files_40s)} 40S CSV files and {len(csv_files_60s)} 60S CSV files to process")
    
    # Process 40S particles first to get their states
    forty_s_particles = {}
    for csv_path in csv_files_40s:
        df = pd.read_csv(csv_path)
        for _, particle in df.iterrows():
            micrograph_name = Path(particle['micrograph_path']).stem
            key = (micrograph_name, particle['particle_index'])
            forty_s_particles[key] = particle[sort_column]
    
    # Initialize DataFrames to store particles for each category
    category_dfs = {
        '60S_only': [],
        '40S_nonrotated': [],
        '40S_rotated': [],
        'rest': []  # Add category for particles that don't fit other categories
    }
    
    # Process 60S particles
    for csv_path in csv_files_60s:
        print(f"\nProcessing CSV file: {csv_path}")
        
        # Read the CSV file
        df = pd.read_csv(csv_path)
        
        # Group particles by micrograph
        micrograph_groups = df.groupby('micrograph_path')
        
        for micrograph_path, particles in micrograph_groups:
            print(f"Processing micrograph: {micrograph_path}")
            
            # Get pixel size from first particle in the group
            pixel_size = particles.iloc[0]['refined_pixel_size']
            
            # Load the micrograph
            with mrcfile.open(micrograph_path) as mrc:
                micrograph = mrc.data
            
            # Initialize lists to store particles and their metadata
            particle_data = []
            particle_categories = []  # Store which category each particle belongs to
            
            # Process each particle
            for _, particle in particles.iterrows():
                # Get particle top-left coordinates
                x_start = int(particle['pos_x'])
                y_start = int(particle['pos_y'])
                
                # Calculate box boundaries
                x_end = min(micrograph.shape[-1], x_start + box_size)
                y_end = min(micrograph.shape[-2], y_start + box_size)
                
                # Skip if the box is empty or invalid
                if x_start >= x_end or y_start >= y_end:
                    print(f"Warning: Invalid box coordinates for particle at ({x_start}, {y_start})")
                    continue
                
                # Extract particle
                particle_img = micrograph[..., y_start:y_end, x_start:x_end]
                
                # Create padded image
                padded_img = np.zeros((box_size, box_size), dtype=micrograph.dtype)
                
                # Calculate the region to copy
                copy_height = min(particle_img.shape[-2], box_size)
                copy_width = min(particle_img.shape[-1], box_size)
                
                # Copy the valid region
                padded_img[:copy_height, :copy_width] = particle_img[..., :copy_height, :copy_width]
                
                # Check 40S state and determine category
                micrograph_name = Path(micrograph_path).stem
                key = (micrograph_name, particle['particle_index'])
                
                category = '60S_only'  # Default category
                if key in forty_s_particles:
                    psi_value = forty_s_particles[key]
                    if -2.0 <= psi_value <= 2.0:
                        category = '40S_nonrotated'
                    elif -12.0 <= psi_value <= -4.5:
                        category = '40S_rotated'
                    else:
                        category = 'rest'  # 40S particle exists but psi is outside our ranges
                
                # Store particle data and its category
                particle_data.append({
                    'image': padded_img,
                    'metadata': particle
                })
                particle_categories.append(category)
            
            if not particle_data:
                print(f"Warning: No valid particles found in {micrograph_path}")
                continue
            
            # Create single stack for all particles
            particle_stack = np.stack([p['image'] for p in particle_data])
            
            # Create output filename (just one stack per micrograph)
            micrograph_name = Path(micrograph_path).stem
            output_path = os.path.join(output_dir, f"{micrograph_name}.mrcs")
            
            # Save the stack
            with mrcfile.new(output_path, overwrite=True) as mrc:
                mrc.set_data(particle_stack)
                mrc.voxel_size = pixel_size
            
            # Add particles to their respective category DataFrames with their actual stack positions
            for idx, (particle, category) in enumerate(zip(particle_data, particle_categories)):
                particle_df = pd.DataFrame([particle['metadata']])
                particle_df['stack_order'] = idx + 1  # Position in the actual stack
                category_dfs[category].append(particle_df)
    
    # Create star files for each category at the end
    for category, dfs in category_dfs.items():
        if dfs:
            all_particles_df = pd.concat(dfs, ignore_index=True)
            star_file_path = os.path.join(output_dir, f'particles_{category}.star')
            create_star_file(all_particles_df, output_dir, star_file_path, box_size)

    # Create a star file for all particles combined
    all_particles_combined = []
    for dfs in category_dfs.values():
        if dfs:
            all_particles_combined.extend(dfs)

    if all_particles_combined:
        all_particles_df = pd.concat(all_particles_combined, ignore_index=True)
        star_file_path = os.path.join(output_dir, 'particles_all.star')
        create_star_file(all_particles_df, output_dir, star_file_path, box_size)
        print(f"Created combined star file with all particles: {star_file_path}")

if __name__ == "__main__":
    import argparse
    
    parser = argparse.ArgumentParser(description="Process and sort 40S and 60S particles")
    parser.add_argument("input_40s_dir", help="Directory containing 40S input CSV files")
    parser.add_argument("input_60s_dir", help="Directory containing 60S input CSV files")
    parser.add_argument("output_dir", help="Directory to save the output stacks and star files")
    parser.add_argument("--box-size", type=int, default=256, help="Size of the square box to crop around each particle")
    parser.add_argument("--sort-column", default='original_offset_psi',
                      help="Column name to use for sorting particles (default: original_offset_psi)")
    parser.add_argument("--csv-suffix-40s", default='_results.csv',
                      help="Suffix pattern to match 40S CSV files (default: _results.csv)")
    parser.add_argument("--csv-suffix-60s", default='_results.csv',
                      help="Suffix pattern to match 60S CSV files (default: _results.csv)")
    
    args = parser.parse_args()
    
    create_particle_stacks(args.input_40s_dir, args.input_60s_dir, args.output_dir, 
                         args.box_size, args.sort_column, 
                         args.csv_suffix_40s, args.csv_suffix_60s)
# Out:
# Found 60 40S CSV files and 70 60S CSV files to process
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_291_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_291_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_260_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_260_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_277_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_277_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_245_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_245_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_246_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_246_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_225_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_225_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_226_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_226_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_221_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_221_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_215_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_215_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_224_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_224_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_282_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_282_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_272_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_272_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_273_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_273_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_240_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_240_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_248_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_248_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_276_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_276_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_284_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_284_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_280_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_280_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_233_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_233_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_237_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_237_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_269_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_269_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_223_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_223_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_244_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_244_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_287_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_287_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_259_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_259_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_286_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_286_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_230_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_230_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_213_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_213_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_234_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_234_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_275_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_275_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_252_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_252_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_288_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_288_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_238_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_238_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_243_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_243_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_258_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_258_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_247_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_247_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_283_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_283_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_214_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_214_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_232_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_232_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_279_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_279_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_271_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_271_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_253_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_253_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_281_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_281_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_290_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_290_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_255_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_255_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_217_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_217_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_228_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_228_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_251_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_251_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_229_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_229_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_268_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_268_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_270_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_270_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_227_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_227_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_274_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_274_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_216_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_216_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_250_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_250_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_264_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_264_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_222_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_222_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_219_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_219_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_263_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_263_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_220_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_220_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_218_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_218_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_278_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_278_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_262_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_262_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_241_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_241_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_236_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_236_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_261_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_261_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_235_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_235_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_242_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_242_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_239_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/mgraphs_25/xenon_239_000_0.0_DWS.mrc
#
# Processing CSV file: xe30kv/results_refine_tm_60S_2/xenon_231_000_0.0_DWS_refined_results.csv
# Processing micrograph: /home/data/jdickerson/Leopard-EM_paper_data/xe30kv/all_mgraphs/xenon_231_000_0.0_DWS.mrc
# Created star file: xe30kv/extracted_60S_constrained_2/particles_60S_only.star
# Created star file: xe30kv/extracted_60S_constrained_2/particles_40S_nonrotated.star
# Created star file: xe30kv/extracted_60S_constrained_2/particles_40S_rotated.star
# Created star file: xe30kv/extracted_60S_constrained_2/particles_rest.star
# Created star file: xe30kv/extracted_60S_constrained_2/particles_all.star
# Created combined star file with all particles: xe30kv/extracted_60S_constrained_2/particles_all.star

# %% [markdown]
# Next, we will reconstruct these with RELION

# %%
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_60S_only.star --o xe30kv/reconstructions/reconstruct_60S-only_half1.mrc --ctf --subset 1
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_60S_only.star --o xe30kv/reconstructions/reconstruct_60S-only_half2.mrc --ctf --subset 2
# Next, we'll run the following command to generate a 3D volume from the 60S particles with rotated 40S
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_40S_rotated.star --o xe30kv/reconstructions/reconstruct_60S-rotated_half1.mrc --ctf --subset 1
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_40S_rotated.star --o xe30kv/reconstructions/reconstruct_60S-rotated_half2.mrc --ctf --subset 2

# Next, we'll run the following command to generate a 3D volume from the 60S particles with non-rotated 40S
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_40S_nonrotated.star --o xe30kv/reconstructions/reconstruct_60S-nonrotated_half1.mrc --ctf --subset 1
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_40S_nonrotated.star --o xe30kv/reconstructions/reconstruct_60S-nonrotated_half2.mrc --ctf --subset 2

# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_all.star --o xe30kv/reconstructions/reconstruct_60S-all_half1.mrc --ctf --subset 1
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_all.star --o xe30kv/reconstructions/reconstruct_60S-all_half2.mrc --ctf --subset 2
# Out:
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
#   40/  40 sec ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-only_half1.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
#   40/  40 sec ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-only_half2.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
#   20/  20 sec ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-rotated_half1.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
#   20/  20 sec ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-rotated_half2.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
# 1.10/1.10 min ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-nonrotated_half1.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
#   57/  57 sec ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-nonrotated_half2.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
# 2.42/2.42 min ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-all_half1.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
# 2.10/2.10 min ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-all_half2.mrc

# %% [markdown]
# We will also reconstruct all as well as subsets

# %%
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_60S_only.star --o xe30kv/reconstructions/reconstruct_60S-only_all.mrc --ctf
# Next, we'll run the following command to generate a 3D volume from the 60S particles with rotated 40S
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_40S_rotated.star --o xe30kv/reconstructions/reconstruct_60S-rotated_all.mrc --ctf

# Next, we'll run the following command to generate a 3D volume from the 60S particles with non-rotated 40S
# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_40S_nonrotated.star --o xe30kv/reconstructions/reconstruct_60S-nonrotated_all.mrc --ctf

# !relion_reconstruct --i xe30kv/extracted_60S_constrained_2/particles_all.star --o xe30kv/reconstructions/reconstruct_60S-all_all.mrc --ctf
# Out:
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
# 1.45/1.45 min ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-only_all.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
#   39/  39 sec ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-rotated_all.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
# 1.73/1.73 min ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-nonrotated_all.mrc
#  + Taking data dimensions from the first optics group: 2
#  + Taking angpix from the first optics group: 0.936
#  + Back-projecting all images ...
# 4.18/4.18 min ............................................................~~(,_,">
#  + Starting the reconstruction ...
#  + Done! Written output map in: xe30kv/reconstructions/reconstruct_60S-all_all.mrc

# %% [markdown]
# Now we are going to invert the contrast in the maps. We will also lowpass filter the full maps, and use these for masking

# %%
# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-only_half1.mrc --o xe30kv/reconstructions/reconstruct_60S-only_half1_invert.mrc --multiply_constant -1
# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-only_half2.mrc --o xe30kv/reconstructions/reconstruct_60S-only_half2_invert.mrc --multiply_constant -1

# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-rotated_half1.mrc --o xe30kv/reconstructions/reconstruct_60S-rotated_half1_invert.mrc --multiply_constant -1
# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-rotated_half2.mrc --o xe30kv/reconstructions/reconstruct_60S-rotated_half2_invert.mrc --multiply_constant -1

# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-nonrotated_half1.mrc --o xe30kv/reconstructions/reconstruct_60S-nonrotated_half1_invert.mrc --multiply_constant -1
# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-nonrotated_half2.mrc --o xe30kv/reconstructions/reconstruct_60S-nonrotated_half2_invert.mrc --multiply_constant -1

# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-all_half1.mrc --o xe30kv/reconstructions/reconstruct_60S-all_half1_invert.mrc --multiply_constant -1
# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-all_half2.mrc --o xe30kv/reconstructions/reconstruct_60S-all_half2_invert.mrc --multiply_constant -1
# Out:
#    5/   5 sec ............................................................~~(,_,">
#    5/   5 sec ............................................................~~(,_,">
#    4/   4 sec ............................................................~~(,_,">
#    4/   4 sec ............................................................~~(,_,">
#    4/   4 sec ............................................................~~(,_,">
#    6/   6 sec ............................................................~~(,_,">
#    3/   3 sec ............................................................~~(,_,">
#    2/   2 sec ............................................................~~(,_,">

# %%
# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-only_ctf.mrc --o xe30kv/reconstructions/reconstruct_60S-only_ctf_invert_lp30.mrc --lowpass 30 --multiply_constant -1

# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-rotated_ctf.mrc --o xe30kv/reconstructions/reconstruct_60S-rotated_ctf_invert_lp30.mrc --lowpass 30 --multiply_constant -1

# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-nonrotated_ctf.mrc --o xe30kv/reconstructions/reconstruct_60S-nonrotated_ctf_invert_lp30.mrc --lowpass 30 --multiply_constant -1

# !relion_image_handler --i xe30kv/reconstructions/reconstruct_60S-all_all.mrc --o xe30kv/reconstructions/reconstruct_60S-all_ctf_invert_lp30.mrc --lowpass 30 --multiply_constant -1
# Out:
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#   10/  10 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#    9/   9 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#    9/   9 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#    6/   6 sec ............................................................~~(,_,">

# %% [markdown]
# I'm going to look at the lp30 mrc's so we can set a threshold for the mask creation.
# First, I'm going to make a wide spherical mask I will multiply with the created mask. The reason I like to do this is as a drop sigma, noise appears at the edge first. By masking the edge out, I can use a lower sigma and thus have a less tight mask.

# %%
# !relion_mask_create --denovo --box_size 512 --outer_radius 400 --o xe30kv/masks/spherical_mask_wide.mrc --j 16
# Out:
# WARNING: The pixel size was not specified. 1.00 is set to the output mask.
#  Done creating mask! Written out: xe30kv/masks/spherical_mask_wide.mrc

# %%
# !relion_mask_create --i xe30kv/reconstructions/reconstruct_60S-only_ctf_invert_lp30.mrc --o xe30kv/masks/60S_only_mask.mrc --extend_inimask 6 --width_soft_edge 6 --ini_threshold 0.0012 --j 20

# !relion_mask_create --i xe30kv/reconstructions/reconstruct_60S-rotated_ctf_invert_lp30.mrc --o xe30kv/masks/60S_rotated_mask.mrc --extend_inimask 6 --width_soft_edge 6 --ini_threshold 0.0016 --j 20

# !relion_mask_create --i xe30kv/reconstructions/reconstruct_60S-nonrotated_ctf_invert_lp30.mrc --o xe30kv/masks/60S_nonrotated_mask.mrc --extend_inimask 6 --width_soft_edge 6 --ini_threshold 0.0014 --j 20

# !relion_mask_create --i xe30kv/reconstructions/reconstruct_60S-all_ctf_invert_lp30.mrc --o xe30kv/masks/60S_all_mask.mrc --extend_inimask 6 --width_soft_edge 6 --ini_threshold 0.0013 --j 20
# Out:
#  Creating a mask ...
# WARNING: The pixel size (--angpix) was not specified.
#          The value in the input image header (= 0.936) is used instead.
# == Extending initial binary mask ...
#   24/  24 sec ............................................................~~(,_,">
# == Making a soft edge on the extended mask ...
#   24/  24 sec ............................................................~~(,_,">
#  Done creating mask! Written out: xe30kv/masks/60S_only_mask.mrc
#  Creating a mask ...
# WARNING: The pixel size (--angpix) was not specified.
#          The value in the input image header (= 0.936) is used instead.
# == Extending initial binary mask ...
#   23/  23 sec ............................................................~~(,_,">
# == Making a soft edge on the extended mask ...
#   23/  23 sec ............................................................~~(,_,">
#  Done creating mask! Written out: xe30kv/masks/60S_rotated_mask.mrc
#  Creating a mask ...
# WARNING: The pixel size (--angpix) was not specified.
#          The value in the input image header (= 0.936) is used instead.
# == Extending initial binary mask ...
#   24/  24 sec ............................................................~~(,_,">
# == Making a soft edge on the extended mask ...
#   25/  25 sec ............................................................~~(,_,">
#  Done creating mask! Written out: xe30kv/masks/60S_nonrotated_mask.mrc
#  Creating a mask ...
# WARNING: The pixel size (--angpix) was not specified.
#          The value in the input image header (= 0.936) is used instead.
# == Extending initial binary mask ...
#   23/  23 sec ............................................................~~(,_,">
# == Making a soft edge on the extended mask ...
#   25/  25 sec ............................................................~~(,_,">
#  Done creating mask! Written out: xe30kv/masks/60S_all_mask.mrc

# %% [markdown]
# I will now multiply witht the spherical mask

# %%
import mrcfile
import numpy as np
from pathlib import Path
import sys

sys.argv = [
    'multiply_masks_with_spherical.py',
    'xe30kv/masks/',
    'xe30kv/masks/spherical_mask_wide.mrc'
]

def create_spherical_mask(size, radius=None):
    """Create a spherical mask with soft edges."""
    if radius is None:
        radius = size // 2 - 2  # Default to slightly smaller than half the box
    
    # Create coordinate arrays
    x = np.arange(size) - size // 2
    y = np.arange(size) - size // 2
    z = np.arange(size) - size // 2
    X, Y, Z = np.meshgrid(x, y, z)
    
    # Calculate distance from center
    R = np.sqrt(X**2 + Y**2 + Z**2)
    
    # Create soft-edged mask
    mask = np.ones_like(R, dtype=np.float32)
    edge_width = 5  # Width of soft edge in pixels
    mask[R > radius] = 0
    edge_mask = (R > (radius - edge_width)) & (R <= radius)
    mask[edge_mask] = 0.5 * (1 + np.cos(np.pi * (R[edge_mask] - (radius - edge_width)) / edge_width))
    
    return mask

def multiply_masks_with_spherical(input_dir, spherical_mask_path, output_dir=None):
    """
    Multiply category masks with an existing spherical mask.
    
    Args:
        input_dir (str): Directory containing the input masks
        spherical_mask_path (str): Path to the spherical mask file
        output_dir (str, optional): Directory to save output masks. If None, uses input_dir
    """
    if output_dir is None:
        output_dir = input_dir
    
    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Specific mask files to process
    mask_files = [
        '60S_all_mask.mrc',
        '60S_nonrotated_mask.mrc',
        '60S_rotated_mask.mrc',
        '60S_only_mask.mrc'
    ]
    
    # Load the spherical mask
    print(f"Loading spherical mask from {spherical_mask_path}")
    with mrcfile.open(spherical_mask_path) as mrc:
        spherical_mask = mrc.data
    
    # Process each mask
    for mask_name in mask_files:
        mask_path = Path(input_dir) / mask_name
        if not mask_path.exists():
            print(f"Warning: Mask not found: {mask_path}")
            continue
        
        print(f"Processing {mask_path}")
        
        # Read the mask
        with mrcfile.open(mask_path) as mrc:
            mask_data = mrc.data
        
        # Multiply with spherical mask
        multiplied_mask = mask_data * spherical_mask
        
        # Save the result
        output_path = Path(output_dir) / f"{mask_path.stem}_mult.mrc"
        with mrcfile.new(output_path, overwrite=True) as mrc:
            mrc.set_data(multiplied_mask)
        
        print(f"Saved multiplied mask to {output_path}")

if __name__ == "__main__":
    import argparse
    
    parser = argparse.ArgumentParser(description="Multiply category masks with a spherical mask")
    parser.add_argument("input_dir", help="Directory containing the input masks")
    parser.add_argument("spherical_mask", help="Path to the spherical mask file")
    parser.add_argument("--output-dir", help="Directory to save output masks (default: same as input)")
    
    args = parser.parse_args()
    multiply_masks_with_spherical(args.input_dir, args.spherical_mask, args.output_dir)
# Out:
# Loading spherical mask from xe30kv/masks/spherical_mask_wide.mrc
# Processing xe30kv/masks/60S_all_mask.mrc
# Saved multiplied mask to xe30kv/masks/60S_all_mask_mult.mrc
# Processing xe30kv/masks/60S_nonrotated_mask.mrc
# Saved multiplied mask to xe30kv/masks/60S_nonrotated_mask_mult.mrc
# Processing xe30kv/masks/60S_rotated_mask.mrc
# Saved multiplied mask to xe30kv/masks/60S_rotated_mask_mult.mrc
# Processing xe30kv/masks/60S_only_mask.mrc
# Saved multiplied mask to xe30kv/masks/60S_only_mask_mult.mrc

# %% [markdown]
# It's now time to postprocess to get the outputs maps

# %%
# !relion_postprocess --i xe30kv/reconstructions/reconstruct_60S-rotated_half1_invert.mrc --o xe30kv_reconstructions/reconstruct_60S-rotated_postprocessed --mask xe30kv/masks/60S_rotated_mask_mult.mrc --mtf mtf_falcon4EC_300kV.star --auto_bfac

# !relion_postprocess --i xe30kv/reconstructions/reconstruct_60S-nonrotated_half1_invert.mrc --o xe30kv_reconstructions/reconstruct_60S-nonrotated_postprocessed --mask xe30kv/masks/60S_nonrotated_mask_mult.mrc --mtf mtf_falcon4EC_300kV.star --auto_bfac

# !relion_postprocess --i xe30kv/reconstructions/reconstruct_60S-only_half1_invert.mrc --o xe30kv_reconstructions/reconstruct_60S-only_postprocessed --mask xe30kv/masks/60S_only_mask_mult.mrc --mtf mtf_falcon4EC_300kV.star --auto_bfac

# !relion_postprocess --i xe30kv/reconstructions/reconstruct_60S-all_half1_invert.mrc --o xe30kv_reconstructions/reconstruct_60S-all_postprocessed --mask xe30kv/masks/60S_all_mask_mult.mrc --mtf mtf_falcon4EC_300kV.star --auto_bfac
# Out:
# == Reading input half-reconstructions:
#   + half1-map:                     xe30kv/reconstructions/reconstruct_60S-rotated_half1_invert.mrc
#   + half2-map:                     xe30kv/reconstructions/reconstruct_60S-rotated_half2_invert.mrc
# WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#  + --mtf_angpix was not provided, assuming pixel size in raw micrographs is the same as in particles, 0.936 A/px.
# == Using a user-provided mask ...
#   + input mask:                    xe30kv/masks/60S_rotated_mask_mult.mrc
#   + fraction f (solvent mask based): 7.88028
#   + molecular weight inside protein mask: 5.38502e+06
# == Masking input maps ...
#   + randomize phases beyond:       95.8464 Angstroms
# == Dividing map by the MTF of the detector ...
#   + mtf STAR-file:                 mtf_falcon4EC_300kV.star
# == Applying sqrt(2*FSC/(FSC+1)) weighting (as in Rosenthal & Henderson, 2003) ...
# == Fitting straight line through Guinier plot to find B-factor ...
#   + fit from resolution:           10
#   + fit until resolution:          0
#   + slope of fit:                  -7.6407
#   + intercept of fit:              -14.8272
#   + correlation of fit:            0.622332
#   + apply b-factor of:             -30.5628
# == Writing output files ...
#   + Processed map:                 xe30kv_reconstructions/reconstruct_60S-rotated_postprocessed.mrc
#   + Processed masked map:          xe30kv_reconstructions/reconstruct_60S-rotated_postprocessed_masked.mrc
#   + Metadata file:                 xe30kv_reconstructions/reconstruct_60S-rotated_postprocessed.star
#   + FINAL RESOLUTION:              6.74975
# == Reading input half-reconstructions:
#   + half1-map:                     xe30kv/reconstructions/reconstruct_60S-nonrotated_half1_invert.mrc
#   + half2-map:                     xe30kv/reconstructions/reconstruct_60S-nonrotated_half2_invert.mrc
# WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#  + --mtf_angpix was not provided, assuming pixel size in raw micrographs is the same as in particles, 0.936 A/px.
# == Using a user-provided mask ...
#   + input mask:                    xe30kv/masks/60S_nonrotated_mask_mult.mrc
#   + fraction f (solvent mask based): 7.43504
#   + molecular weight inside protein mask: 5.7075e+06
# == Masking input maps ...
#   + randomize phases beyond:       36.864 Angstroms
# == Dividing map by the MTF of the detector ...
#   + mtf STAR-file:                 mtf_falcon4EC_300kV.star
# == Applying sqrt(2*FSC/(FSC+1)) weighting (as in Rosenthal & Henderson, 2003) ...
# == Fitting straight line through Guinier plot to find B-factor ...
#   + fit from resolution:           10
#   + fit until resolution:          0
#   + slope of fit:                  -7.27522
#   + intercept of fit:              -14.9516
#   + correlation of fit:            0.632469
#   + apply b-factor of:             -29.1009
# == Writing output files ...
#   + Processed map:                 xe30kv_reconstructions/reconstruct_60S-nonrotated_postprocessed.mrc
#   + Processed masked map:          xe30kv_reconstructions/reconstruct_60S-nonrotated_postprocessed_masked.mrc
#   + Metadata file:                 xe30kv_reconstructions/reconstruct_60S-nonrotated_postprocessed.star
#   + FINAL RESOLUTION:              4.27886
# == Reading input half-reconstructions:
#   + half1-map:                     xe30kv/reconstructions/reconstruct_60S-only_half1_invert.mrc
#   + half2-map:                     xe30kv/reconstructions/reconstruct_60S-only_half2_invert.mrc
# WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#  + --mtf_angpix was not provided, assuming pixel size in raw micrographs is the same as in particles, 0.936 A/px.
# == Using a user-provided mask ...
#   + input mask:                    xe30kv/masks/60S_only_mask_mult.mrc
#   + fraction f (solvent mask based): 7.58292
#   + molecular weight inside protein mask: 5.5962e+06
# == Masking input maps ...
#   + randomize phases beyond:       68.4617 Angstroms
# == Dividing map by the MTF of the detector ...
#   + mtf STAR-file:                 mtf_falcon4EC_300kV.star
# == Applying sqrt(2*FSC/(FSC+1)) weighting (as in Rosenthal & Henderson, 2003) ...
# == Fitting straight line through Guinier plot to find B-factor ...
#   + fit from resolution:           10
#   + fit until resolution:          0
#   + slope of fit:                  -8.96427
#   + intercept of fit:              -15.0153
#   + correlation of fit:            0.678778
#   + apply b-factor of:             -35.8571
# == Writing output files ...
#   + Processed map:                 xe30kv_reconstructions/reconstruct_60S-only_postprocessed.mrc
#   + Processed masked map:          xe30kv_reconstructions/reconstruct_60S-only_postprocessed_masked.mrc
#   + Metadata file:                 xe30kv_reconstructions/reconstruct_60S-only_postprocessed.star
#   + FINAL RESOLUTION:              5.04455
# == Reading input half-reconstructions:
#   + half1-map:                     xe30kv/reconstructions/reconstruct_60S-all_half1_invert.mrc
#   + half2-map:                     xe30kv/reconstructions/reconstruct_60S-all_half2_invert.mrc
# WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#  + --mtf_angpix was not provided, assuming pixel size in raw micrographs is the same as in particles, 0.936 A/px.
# == Using a user-provided mask ...
#   + input mask:                    xe30kv/masks/60S_all_mask_mult.mrc
#   + fraction f (solvent mask based): 7.40223
#   + molecular weight inside protein mask: 5.7328e+06
# == Masking input maps ...
#   + randomize phases beyond:       18.432 Angstroms
# == Dividing map by the MTF of the detector ...
#   + mtf STAR-file:                 mtf_falcon4EC_300kV.star
# == Applying sqrt(2*FSC/(FSC+1)) weighting (as in Rosenthal & Henderson, 2003) ...
# == Fitting straight line through Guinier plot to find B-factor ...
#   + fit from resolution:           10
#   + fit until resolution:          0
#   + slope of fit:                  -8.21661
#   + intercept of fit:              -15.1417
#   + correlation of fit:            0.589074
#   + apply b-factor of:             -32.8664
# == Writing output files ...
#   + Processed map:                 xe30kv_reconstructions/reconstruct_60S-all_postprocessed.mrc
#   + Processed masked map:          xe30kv_reconstructions/reconstruct_60S-all_postprocessed_masked.mrc
#   + Metadata file:                 xe30kv_reconstructions/reconstruct_60S-all_postprocessed.star
#   + FINAL RESOLUTION:              3.86477

# %% [markdown]
# Finally, we low-pass filter them for ease of visualization.

# %%
# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-nonrotated_postprocessed.mrc --o xe30kv_reconstructions/reconstruct_60S-nonrotated_postprocessed_lp8.mrc --lowpass 8

# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-rotated_postprocessed.mrc --o xe30kv_reconstructions/reconstruct_60S-rotated_postprocessed_lp8.mrc --lowpass 8

# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-only_postprocessed.mrc --o xe30kv_reconstructions/reconstruct_60S-only_postprocessed_lp8.mrc --lowpass 8

# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-all_postprocessed.mrc --o xe30kv_reconstructions/reconstruct_60S-all_postprocessed_lp8.mrc --lowpass 8

# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-nonrotated_postprocessed_masked.mrc --o xe30kv_reconstructions/reconstruct_60S-nonrotated_postprocessed_masked_lp8.mrc --lowpass 8

# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-rotated_postprocessed_masked.mrc --o xe30kv_reconstructions/reconstruct_60S-rotated_postprocessed_masked_lp8.mrc --lowpass 8

# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-only_postprocessed_masked.mrc --o xe30kv_reconstructions/reconstruct_60S-only_postprocessed_masked_lp8.mrc --lowpass 8

# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-all_postprocessed_masked.mrc --o xe30kv_reconstructions/reconstruct_60S-all_postprocessed_masked_lp8.mrc --lowpass 8
# Out:
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#    8/   8 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#    9/   9 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#   10/  10 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#    7/   7 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#   11/  11 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#   10/  10 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#   10/  10 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#    7/   7 sec ............................................................~~(,_,">

# %% [markdown]
# Let's also maybe do some local resolution estimation.
# I'm going to make a mask for just the SSU body for this

# %%
# !relion_mask_create --i xe30kv/reconstructions/SSU-body-mask_scaled.mrc --o xe30kv/masks/untreated_all_SSU-body_mask.mrc --extend_inimask 10 --width_soft_edge 10 --ini_threshold 0.0013 --j 20
# Out:
#  Creating a mask ...
# WARNING: The pixel size (--angpix) was not specified.
#          The value in the input image header (= 0.936) is used instead.
# == Extending initial binary mask ...
# 1.77/1.77 min ............................................................~~(,_,">
# == Making a soft edge on the extended mask ...
# 1.75/1.75 min ............................................................~~(,_,">
#  Done creating mask! Written out: xe30kv/masks/untreated_all_SSU-body_mask.mrc

# %%
# !relion_postprocess --i xe30kv/reconstructions/reconstruct_60S-all_half1_invert.mrc --o xe30kv_reconstructions/reconstruct_60S-all_postprocessed --mask xe30kv/masks/untreated_all_SSU-body_mask.mrc --mtf mtf_falcon4EC_300kV.star --auto_bfac
# Out:
# == Reading input half-reconstructions:
#   + half1-map:                     xe30kv/reconstructions/reconstruct_60S-all_half1_invert.mrc
#   + half2-map:                     xe30kv/reconstructions/reconstruct_60S-all_half2_invert.mrc
# WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#  + --mtf_angpix was not provided, assuming pixel size in raw micrographs is the same as in particles, 0.936 A/px.
# == Using a user-provided mask ...
#   + input mask:                    xe30kv/masks/untreated_all_SSU-body_mask.mrc
#   + fraction f (solvent mask based): 32.6347
#   + molecular weight inside protein mask: 1.30032e+06
# == Masking input maps ...
#   + randomize phases beyond:       18.432 Angstroms
# == Dividing map by the MTF of the detector ...
#   + mtf STAR-file:                 mtf_falcon4EC_300kV.star
# == Applying sqrt(2*FSC/(FSC+1)) weighting (as in Rosenthal & Henderson, 2003) ...
# == Fitting straight line through Guinier plot to find B-factor ...
#   + fit from resolution:           10
#   + fit until resolution:          0
#   + slope of fit:                  -13.0033
#   + intercept of fit:              -15.3485
#   + correlation of fit:            0.793739
#   + apply b-factor of:             -52.0131
# == Writing output files ...
#   + Processed map:                 xe30kv_reconstructions/reconstruct_60S-all_postprocessed.mrc
#   + Processed masked map:          xe30kv_reconstructions/reconstruct_60S-all_postprocessed_masked.mrc
#   + Metadata file:                 xe30kv_reconstructions/reconstruct_60S-all_postprocessed.star
#   + FINAL RESOLUTION:              5.04455

# %%
# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-all_postprocessed_masked.mrc --o xe30kv_reconstructions/reconstruct_60S-all_postprocessed_masked_SSU-body_lp8.mrc --lowpass 8
# !relion_image_handler --i xe30kv_reconstructions/reconstruct_60S-all_postprocessed_masked.mrc --o xe30kv_reconstructions/reconstruct_60S-all_postprocessed_masked_SSU-body_lp20.mrc --lowpass 20
# Out:
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#    6/   6 sec ............................................................~~(,_,">
# 000/??? sec ~~(,_,">                                                          [oo]WARNING: You did not specify --angpix. The pixel size in the image header, 0.936 A/px, is used.
#    6/   6 sec ............................................................~~(,_,">
